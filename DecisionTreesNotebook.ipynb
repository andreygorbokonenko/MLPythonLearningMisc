# %% [markdown]
# TEST MARKDOWN

# %%
import pandas as pd

# %%
loandata = pd.read_csv("loan.csv")

# %%
loandata.describe()
# Out:
#           Income  Loan Amount
# count  30.000000    30.000000
# mean   18.766667    51.966667
# std     8.572946    34.055212
# min     5.000000     8.000000
# 25%    13.000000    21.250000
# 50%    18.000000    49.000000
# 75%    25.500000    79.500000
# max    34.000000   110.000000

# %%
loandata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Income       30 non-null     int64
#  1   Loan Amount  30 non-null     int64
#  2   Default      30 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes

# %%
import  seaborn as  sns

# %%
ax = sns.boxplot(data=loandata, x= 'Default', y='Income')

# %%
ax = sns.boxplot(data = loandata, x = 'Default', y = 'Loan Amount')

# %%
ax = sns.scatterplot(data=loandata, x = 'Default', y = 'Loan Amount')

# %%
ax = sns.scatterplot(data=loandata, x = 'Default', y = 'Income')

# %%
ax = sns.scatterplot(data = loandata, x='Income' , y = 'Loan Amount')

# %%
from matplotlib import pyplot as plt

# %%
ax = sns.scatterplot(data = loandata, 
                     x = 'Loan Amount', 
                     y = 'Income', 
                     hue = 'Default', 
                     style = 'Default', 
                     markers = ['^','o'], 
                     s = 150)
ax = plt.legend(bbox_to_anchor = (1.02, 1), loc = 'upper left')

# %%
y = loandata[['Default']]

# %%
y.describe()
# Out:
#        Default
# count       30
# unique       2
# top         No
# freq        17

# %%
z = loandata['Default']
z.describe()
# Out:
# count     30
# unique     2
# top       No
# freq      17
# Name: Default, dtype: object

# %%
x = loandata[['Income', 'Loan Amount']]

# %%
x.head()
# Out:
#    Income  Loan Amount
# 0      15            8
# 1      30            8
# 2       5            9
# 3      22           10
# 4      33           12

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(x,y,train_size=0.8,stratify= y, random_state= 1234)

# %%
x_train.describe()
# Out:
#           Income  Loan Amount
# count  24.000000    24.000000
# mean   18.125000    48.333333
# std     8.383796    32.145953
# min     5.000000     8.000000
# 25%    12.750000    20.750000
# 50%    17.000000    43.000000
# 75%    24.500000    76.500000
# max    34.000000   110.000000

# %%
x_test.describe()
# Out:
#           Income  Loan Amount
# count   6.000000     6.000000
# mean   21.333333    66.500000
# std     9.647107    40.697666
# min     7.000000    12.000000
# 25%    15.500000    36.750000
# 50%    23.500000    70.000000
# 75%    27.000000   101.000000
# max    33.000000   110.000000

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(random_state=1234)

# %%
model = classifier.fit(X=x_train,y=y_train)

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.5

# %%
from sklearn import tree

# %%
tree.plot_tree(model)
# Out:
# [Text(0.4444444444444444, 0.9, 'x[0] <= 14.5\ngini = 0.486\nsamples = 24\nvalue = [14, 10]'),
#  Text(0.2222222222222222, 0.7, 'x[0] <= 12.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.3333333333333333, 0.8, 'True  '),
#  Text(0.1111111111111111, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3333333333333333, 0.5, 'x[0] <= 13.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2222222222222222, 0.3, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.7, 'x[0] <= 22.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.5555555555555556, 0.8, '  False'),
#  Text(0.5555555555555556, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7777777777777778, 0.5, 'x[0] <= 25.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.6666666666666666, 0.3, 'x[0] <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
# ...

# %%
z = loandata[['Income', 'Loan Amount']]

# %%
z
# Out:
#     Income  Loan Amount
# 0       15            8
# 1       30            8
# 2        5            9
# 3       22           10
# 4       33           12
# 5       18           15
# 6       28           20
# 7       12           21
# 8       24           22
# 9        9           30
# 10      23           32
# 11      34           32
# 12      13           35
# 13      26           38
# 14       8           48
# 15      23           50
# 16      13           51
# 17      30           53
# 18      26           70
# 19       5           72
# 20      18           76
# 21      13           78
# 22      23           80
# 23      15           85
# 24      24           89
# 25       8           90
# 26      16          100
# 27       7          105
# 28      14          110
# 29      28          110

# %%
model2 = classifier.fit(x_train,y_train)
